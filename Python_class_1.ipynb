# %% [markdown]
# <a href="https://colab.research.google.com/github/kartikgugadaddi771-collab/KARTIK-GUGADADDI/blob/main/Python_class_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
datatypes varaibles datatypes in built functions

# %%
a=10
b=20.6
name="data"

# %%
a=10
## except _ other special characters are not allowed
a=10
### while creating variables it should not start with a number
# Out:
#   File "/tmp/ipykernel_973/1151566379.py", line 3
#     67a=10
#      ^
# SyntaxError: invalid decimal literal

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
async=20
# Out:
#   File "/tmp/ipykernel_973/3130871764.py", line 1
#     async=20
#          ^
# SyntaxError: invalid syntax

# %%
#### Reserve words, keywords we cannot use these as variable names
### use the right name for variable instead of using a,b,c like this names should
### be retail,sales,units, trasactions,age,name,geneder

# %%
pip install packagename

# %%
int, float, string

# %%
a=10
print(a)
print(type(a))
# Out:
# 10
# <class 'int'>

# %%
a=10.2
type(a)
# Out:
# float

# %%
name=" data science machine learning "
type(name)
# Out:
# str

# %%
int,float,str
# Out:
# (int, float, str)

# %%
int('name')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_973/3667560212.py in <cell line: 0>()
# ----> 1 int('name')
#
# ValueError: invalid literal for int() with base 10: 'name'

# %%
type conversion:

  int --> float,string
  float ---> int,string
  string cannot be int,float

# %%
float("data")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_973/1903384473.py in <cell line: 0>()
# ----> 1 float("data")
#
# ValueError: could not convert string to float: 'data'

# %%
type(2+3j)
# Out:
# complex

# %%
a=2+3j
a.real
# Out:
# 2.0

# %%
a.imag
# Out:
# 3.0

# %%
x="data science"

# %%
x
# Out:
# 'data science'

# %%
x="data engineering"
print(x)
# Out:
# data engineering

# %%
x[-4:-2]
# Out:
# ''

# %%
x
# Out:
# 'data engineering'

# %%
print(x[-11:])
print(x[:4])
# Out:
# engineering
# data

# %%
x[-11:4]
# Out:
# ''

# %%
len(x)
x[20]
# Out:
# ''

# %% [markdown]
# ```python
# text = "Edukron Data Science and Data Engineering Batch 2026"
# ```
#
# # Python String Indexing Questions
#
# 1. Write the indexing expression to print **"Edukron"**.
#    ```
#    Answer:
#    ```
#
# 2. Write the indexing expression to print **"Data"** (first occurrence).
#    ```
#    Answer:
#    ```
#
# 3. Write the indexing expression to print **"Science"**.
#    ```
#    Answer:
#    ```
#
# 4. Write the indexing expression to print **"and"**.
#    ```
#    Answer:
#    ```
#
# 5. Write the indexing expression to print **"Data Engineering"**.
#    ```
#    Answer:
#    ```
#
# 6. Write the indexing expression to print **"Engineering"**.
#    ```
#    Answer:
#    ```
#
# 7. Write the indexing expression to print **"Batch"**.
#    ```
#    Answer:
#    ```
#
# 8. Write the indexing expression to print **"2026"**.
#    ```
#    Answer:
#    ```
#
# 9. Write the indexing expression to print **"Science and Data"**.
#    ```
#    Answer:
#    ```
#
# 10. Write the indexing expression to print **"Data Science and Data Engineering Batch"**.
#     ```
#     Answer:
#     ```
# ```

# %%
print("Edukron")
# Out:
# Edukron

# %%
x="Data"
print(x)
# Out:
# Data

# %%
x[0:4]
# Out:
# 'Data'

# %%
x[0:1]
# Out:
# 'D'

# %%
x="Science"
print(x)
# Out:
# Science

# %%
x[0:]
# Out:
# 'Science'

# %%
x[0:7]
# Out:
# 'Science'

# %%
x="and"
print(x)
# Out:
# and

# %%
x[0:]
# Out:
# 'and'

# %%
course="Data Engineering"
print(course)
# Out:
# Data Engineering

# %%
course[0:]
# Out:
# 'Data Engineering'

# %%
course[4:16]
# Out:
# ' Engineering'

# %%
y="Engineering"
print(y)
# Out:
# Engineering

# %%
y[0:]
# Out:
# 'Engineering'

# %%
z="Batch"
print(z)
# Out:
# Batch

# %%
z[0:]
# Out:
# 'Batch'

# %%
h="2026"
print(h)
# Out:
# 2026

# %%
h[0:5]
# Out:
# '2026'

# %%
int="Science and Data"
print(int)
# Out:
# Science and Data

# %%
float="Science and Data"
print(float)
# Out:
# Science and Data

# %%
str="Science and Data"
str[0:16]
# Out:
# 'Science and Data'

# %%
str="Science and Data"
float[0:16]
# Out:
# 'Science and Data'

# %%
x='Data Science and Data Engineering Batch'
print(x)
# Out:
# Data Science and Data Engineering Batch

# %%
str="Data Science and Data Engineering Batch"
str[0:]
# Out:
# 'Data Science and Data Engineering Batch'
